# %%
from SRC.webscraping import scrapeo

# %%
url = 'https://en.wikipedia.org/wiki/List_of_cities_by_sunshine_duration'
x = scrapeo(url)
x
# Out:
#     Country        City Sunshine avg hours
# 10  Denmark  Copenhagen              1,739
# 13  Finland    Helsinki              1,858
# 22  Iceland   Reykjavik              1,326
# 33   Norway        Oslo              1,668
# 43    Spain      Madrid              2,769
# 46   Sweden   Stockholm              1,821

# %%
from SRC.cleanDataset import cleanDF

# %%
df = cleanDF()
df
# Out:
#               male_suicides  female_suicides  total_suicides  population  \
# Country Year
# Denmark 1994          56.67            26.58           83.25   406241.67
#         1995          52.08            24.92           77.00   407425.00
#         1996          52.58            21.75           74.33   409775.00
#         1997          46.67            21.42           68.08   411441.67
#         1998          45.58            18.00           63.58   413033.33
# ...                     ...              ...             ...         ...
# Sweden  2012          68.25            27.92           96.17   745742.42
#         2013          71.83            30.67          102.50   752006.75
#         2014          65.42            30.25           95.67   759543.67
#         2015          70.92            27.58           98.50   759543.67
#         2016          78.20            34.80          113.00   812585.20
#
#               suicides/100k pop   gdp_for_year ($)   gdp_per_capita ($)
# ...

# %%
import pandas as pd
df_limpio = pd.read_csv('OUTPUT/finalDF.csv')

# %%
df_limpio.reset_index()
#df_limpio[['Country', ]]
# Out:
#      index  Unnamed: 0  Country  male_suicides  female_suicides  \
# 0        0           0  Denmark          56.67            26.58
# 1        1           1  Denmark          52.08            24.92
# 2        2           2  Denmark          52.58            21.75
# 3        3           3  Denmark          46.67            21.42
# 4        4           4  Denmark          45.58            18.00
# ..     ...         ...      ...            ...              ...
# 169    169         169   Sweden          68.25            27.92
# 170    170         170   Sweden          71.83            30.67
# 171    171         171   Sweden          65.42            30.25
# 172    172         172   Sweden          70.92            27.58
# 173    173         173   Sweden          78.20            34.80
#
#      total_suicides  population  suicides/100k pop   gdp_for_year ($)   \
# 0             83.25   406241.67              21.10        1.561623e+11
# ...

# %%
df = df.reset_index()
merged = df.merge(x,on='Country')
merged
# Out:
#      index  Country  Year  male_suicides  female_suicides  total_suicides  \
# 0        0  Denmark  1994          56.67            26.58           83.25
# 1        1  Denmark  1995          52.08            24.92           77.00
# 2        2  Denmark  1996          52.58            21.75           74.33
# 3        3  Denmark  1997          46.67            21.42           68.08
# 4        4  Denmark  1998          45.58            18.00           63.58
# ..     ...      ...   ...            ...              ...             ...
# 169    169   Sweden  2012          68.25            27.92           96.17
# 170    170   Sweden  2013          71.83            30.67          102.50
# 171    171   Sweden  2014          65.42            30.25           95.67
# 172    172   Sweden  2015          70.92            27.58           98.50
# 173    173   Sweden  2016          78.20            34.80          113.00
#
#      population  suicides/100k pop   gdp_for_year ($)   gdp_per_capita ($)  \
# ...

# %%
merged.set_index(['Country','Year'])
# Out:
#               index  male_suicides  female_suicides  total_suicides  \
# Country Year
# Denmark 1994      0          56.67            26.58           83.25
#         1995      1          52.08            24.92           77.00
#         1996      2          52.58            21.75           74.33
#         1997      3          46.67            21.42           68.08
#         1998      4          45.58            18.00           63.58
# ...             ...            ...              ...             ...
# Sweden  2012    169          68.25            27.92           96.17
#         2013    170          71.83            30.67          102.50
#         2014    171          65.42            30.25           95.67
#         2015    172          70.92            27.58           98.50
#         2016    173          78.20            34.80          113.00
#
#               population  suicides/100k pop   gdp_for_year ($)   \
# Country Year
# ...

# %%
merged.dtypes
# Out:
# Country                object
# Year                    int64
# male_suicides         float64
# female_suicides       float64
# total_suicides        float64
# population            float64
# suicides/100k pop     float64
#  gdp_for_year ($)     float64
# gdp_per_capita ($)    float64
# City                   object
# Sunshine avg hours     object
# dtype: object

# %%
df = merged[merged['Country']=='Spain']
df
# Out:
#      index Country  Year  male_suicides  female_suicides  total_suicides  \
# 113    113   Spain  1985         152.42            57.08          209.50
# 114    114   Spain  1986         169.33            60.25          229.58
# 115    115   Spain  1987         168.08            65.58          233.67
# 116    116   Spain  1988         179.17            67.50          246.67
# 117    117   Spain  1989         184.42            64.50          248.92
# 118    118   Spain  1990         177.92            67.00          244.92
# 119    119   Spain  1991         178.25            64.75          243.00
# 120    120   Spain  1992         175.33            56.83          232.17
# 121    121   Spain  1993         190.25            62.83          253.08
# 122    122   Spain  1994         202.42            61.83          264.25
# 123    123   Spain  1995         200.67            62.42          263.08
# 124    124   Spain  1996         204.25            72.42          276.67
# ...
